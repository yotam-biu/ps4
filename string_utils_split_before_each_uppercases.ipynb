# %% [markdown]
# <a href="https://colab.research.google.com/github/yotam-biu/ps4/blob/main/string_utils_split_before_each_uppercases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment: Implementing the `split_before_each_uppercases` Function**
#
# You will write a function called `split_before_each_uppercases` that splits a string (e.g., a chemical formula) before each uppercase letter, preserving the letter with its preceding part. The function should return a list of substrings where each part ends just before an uppercase letter.
#
# ---
#
# #### **Example**
#
# ```python
# formula = "H2OCO2NH3Fe"
# result = split_before_each_uppercases(formula)
# print(result)  # Output: ['H2', 'O', 'C', 'O2', 'N', 'H3', 'Fe']

# %% [markdown]
# ---
#
# #### **Code Structure**:
#
# 1. **Initialize the arguments** – Define two indices: one for the starting position (`start`) and one for the ending position (`end`), as well as an empty list (`split_formula`). Those arguments will be updated in the loop.
#
# 2. **Loop through the string** – Iterate over each character in the string starting from the second character.
#
# 3. **Check for uppercase letters** – For each character, use the `.isupper()` string method to check if it is an uppercase letter.
#
# 4. **Update the list** – When an uppercase letter is found, append the substring from `start` to `end` to the list and update `start` to the current `end` position. Then, continue iterating through the string.
#
# 5. **Return the list** – After the loop, append the last part of the string (from `start` to `end`) to the list and return the final list.
#
# ---
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
def split_before_each_uppercases(formula):
    pass # Replace the pass with your code

# %%
# Test it yourself

choose_formula = "Fe3He4B"
split_before_each_uppercases(choose_formula)
# Out:
# ['Fe3', 'He4', 'B']

# %%
# Test it with our test cases


def test_split_before_each_uppercases():
    # Test 1: Normal chemical formula with uppercase letters
    formula = "H2OCO2NH3Fe"
    result = split_before_each_uppercases(formula)
    assert result == ['H2', 'O', 'C', 'O2', 'N', 'H3','Fe'], f"Test 1 Failed: {result}"

    # Test 2: Single part formula with no uppercase letters
    formula = "water"
    result = split_before_each_uppercases(formula)
    assert result == ['water'], f"Test 2 Failed: {result}"

    # Test 3: Formula starting with an uppercase letter
    formula = "NaCl"
    result = split_before_each_uppercases(formula)
    assert result == ['Na', 'Cl'], f"Test 3 Failed: {result}"

    # Test 4: Formula with multiple uppercase letters together
    formula = "C6H12O6B"
    result = split_before_each_uppercases(formula)
    assert result == ['C6', 'H12', 'O6', 'B'], f"Test 4 Failed: {result}"

    # Test 5: Empty string
    formula = ""
    result = split_before_each_uppercases(formula)
    assert result == [], f"Test 5 Failed: {result}"

    print("All tests passed!")

# Run the tests
test_split_before_each_uppercases()
# Out:
# All tests passed!
